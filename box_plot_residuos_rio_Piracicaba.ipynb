# %%
# import packages and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# reading the csv file
data = pd.read_csv('Pira_calib.csv', sep=";", decimal=",", header=0)

# %%
data.head()
# Out:
#      x      y
# 0  6.2  4.892
# 1  5.4  4.705
# 2  6.0  5.950
# 3  4.0  5.326
# 4  1.4  2.124

# %%
# fit simple linear regression model
linear_model = ols('y ~ x', data=data).fit()

# %%
# display model summary
print('regressão de calibração para o Rio Piracicaba')
print('')
print(linear_model.summary())
# Out:
# regressão de calibração para o Rio Piracicaba
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     125.7
# Date:                Tue, 28 May 2024   Prob (F-statistic):           1.17e-20
# Time:                        19:56:47   Log-Likelihood:                -173.50
# No. Observations:                 128   AIC:                             351.0
# Df Residuals:                     126   BIC:                             356.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0967      0.204     10.289      0.000       1.693       2.500
# x              0.4986      0.044     11.211      0.000       0.411       0.587
# ==============================================================================
# Omnibus:                        4.823   Durbin-Watson:                   1.698
# Prob(Omnibus):                  0.090   Jarque-Bera (JB):                5.151
# Skew:                          -0.250   Prob(JB):                       0.0761
# Kurtosis:                       3.846   Cond. No.                         11.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# modify figure size
fig = plt.figure(figsize=(12, 8))

# creating regression plots
fig = sm.graphics.plot_regress_exog(linear_model, 'x', fig=fig)

# %%
# reading the csv file
data2 = pd.read_csv('Pira_pred.csv', sep=";", decimal=",", header=0)

# %%
data2.head()
# Out:
#      x        y
# 0  2.6  3.13719
# 1  6.2  5.49558
# 2  5.0  4.02292
# 3  5.6  5.29728
# 4  3.7  3.60352

# %%
# fit simple linear regression model
linear_model2 = ols('y ~ x', data=data2).fit()

# %%
# display model summary
print('regressão de previsão para o Rio Piracicaba')
print('')
print(linear_model2.summary())
# Out:
# regressão de previsão para o Rio Piracicaba
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     14.95
# Date:                Tue, 28 May 2024   Prob (F-statistic):            0.00113
# Time:                        20:03:16   Log-Likelihood:                -18.892
# No. Observations:                  20   AIC:                             41.78
# Df Residuals:                      18   BIC:                             43.78
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8387      0.568      3.237      0.005       0.645       3.032
# x              0.5150      0.133      3.867      0.001       0.235       0.795
# ==============================================================================
# Omnibus:                        0.020   Durbin-Watson:                   2.677
# Prob(Omnibus):                  0.990   Jarque-Bera (JB):                0.185
# Skew:                           0.063   Prob(JB):                        0.911
# Kurtosis:                       2.545   Cond. No.                         17.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# modify figure size
fig = plt.figure(figsize=(12, 8))

# creating regression plots
fig = sm.graphics.plot_regress_exog(linear_model2, 'x', fig=fig)
